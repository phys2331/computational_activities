# %% [markdown]
# # <center> Homework 2 Guide
#
# ___
#
# ## <center> 13.47
#
# ___
#
# ### <center> Skills Involved
#
# Setting up $\vec{r}$.
#
# Finding the unit vector.
#
# Vector notation.
#
# Electric field due to a point charge.
#
# Net electric field from multiple sources.
#
# ### <center> Problem
#
# ![](Graphics/P13.47.png "Problem 13.47 - Matter and Interactions")
#
# a) Find the electric field at the location of $Q_{3}$, due tao $Q_{1}$.
#
# b) Find the electric field at the location of $Q_{3}$, due to $Q_{2}$.
#
# c) Find the net electric field at the location of $Q_{3}$.
# a
# d) Find the net force on $Q_{3}$.
#
# e) Find the electric field at location A due to $Q_{1}$.
#
# f) Find the electric field at location A due to $Q_{2}$.
#
# g) Find the electric field at location A due to $Q_{3}$.
#
# h) What is the net electric field at location A?
#
# i) If a particle with charge -7 nC were placed at location A, what would be the force on this particle?
#
# ### <center> Important Information
#
# **Objective:** Find the electric field at a given location due to a given charge, find the net electric field at a given location, and find the net force on a given location.
#
# **Given Information:**
#
# * Charges of the three particles ($Q_{1}, Q_{2}, Q_{3}$).
#
# * Coordinates: +x is to the right, +y is up the page, +z is out of the page.
#
# * Each grid square is 1 cm x 1 cm.
#
# **Key Equations:**
#
# \begin{equation*}
# \vec{r} = observed - source
# \end{equation*}
#
# \begin{equation*}
# \frac{1}{4\pi\epsilon_{0}} \frac{q}{|\vec{r}|^{2}} \hat{r}
# \end{equation*}
#
# \begin{equation*}
# \vec{E_{net}} = \vec{E_{1}} + \vec{E_{2}} + \vec{E_{3}} ...
# \end{equation*}
#
# \begin{equation*}
# \vec{F} = q\vec{E}
# \end{equation*}
#
# **References:**
#
# * Definition of Electric Field (Matter and Interactions, p. 517)
#
# * Electric Field of a Point Charge (Matter and Interactions, p. 519)
#
# * The Physics II Student's Guide to Vectors (computational_activities/Additional_Resources/Vectors_Guide.ipynb)
#
#
# **Things to think about:**
#
# * Final - Initial = Observed - Source. What is the location you are observing? What is creating the electric field?
#
# * Units!
#
# * Do particles that are charged feel their own charge? Is finding the electric field at location A different than finding the electric field at the locations of the other charged particles?
#
#
# ___
#
# ## <center> 13.49
#
# ___
#
#
# ### <center> Skills Involved
#
# Finding the charge of a proton or electron.
#
# Electric fields due to a point charge.
#
# * Ions as point charges
#
# Net electric field from multiple sources.
#
# Vectors
#
# Force
#
# ### <center> Problem
#
# ![](Graphics/P13.49.png "Problem 13.49 - Matter and Interactions")
#
# a) Determine the magnitude and direction of the electric field $\vec{E_{A}}$ at location A, r = 143 nm to the left of the $Cl^{-}$ ion.
#
# b) Determine the magnitude and direction of the electric field $\vec{E_{B}}$ at location A, r = 143 nm to the right of the $Cl^{-}$ ion.
#
# c) If an electron is placed at location A, what are the magnitude and direction of the force on the electron?
#
# ### <center> Important Information
#
# **Objective:** Find the magnitude and direction of the electric field at a given location, and find the magnitude and direction of the force at a given location.
#
# **Given Information:**
#
# * There are two ions some distance away from each other: $Fe^{3+}$ and $Cl^{-}$.
#
# * The distance these ions are away from each other.
#
# * The locations of A and B are some r distance away from the $Cl^{-}$ ion.
#
# **Key Equations:**
#
# \begin{equation*}
# |\frac{1}{4\pi\epsilon_{0}} \frac{q}{|\vec{r}|^{2}}|
# \end{equation*}
#
# \begin{equation*}
# \vec{E_{net}} = \vec{E_{1}} + \vec{E_{2}} + \vec{E_{3}} ...
# \end{equation*}
#
# \begin{equation*}
# \vec{F} = q\vec{E}
# \end{equation*}
#
# **References:**
#
# * Charged Particles (Matter and Interactions, p. 514)
#
# * Definition of Electric Field (Matter and Interactions, p. 517)
#
# * Direction of Electric Field (Matter and Interactions, p. 519)
#
# * Magnitude of Electric Field (Matter and Interactions, p. 520)
#
# * The Physics II Student's Guide to Vectors (computational_activities/Additional_Resources/Vectors_Guide.ipynb)
#
# **Things to think about:**
#
# * What does it mean for iron to have a $3^{+}$ charge and chlorine to have a single negative charge?
#
#     * What is the charge? How does this change the electric field equation?
#
# * Can magnitude be negative?
#
#     * If an answer is negative before taking the absolute value, what does this indicate?
# ___
#
# ## <center> 15.22
#
# ___
#
# ### <center> Skills Involved
#
# Location of the center of an object/segment
#
# * Vector notation
#
# * Finding the origin based on a given location
#
# Charge of a segment
#
# * Uniform charge density
#
# Setting up r-vector and finding the unit vector
#
# Understanding approximations
#
# Electric field due to a point charge
#
# Direction of net field due to multiple sources
#
# ### <center> Problem
#
# ![](Graphics/P15.22.png "Problem 15.22 - Matter and Interactions")
#
# a) What is the length of one of these pieces?
#
# b) WHat is the location of the center of piece number 4?
#
# c) How much charge is on piece number 4?
#
# d) Approximating piece 4 as a point charge, what is the electric field at location A due only to piece 4?
#
# e) TO get the net electric field at location A, we would need to calculate due each of the 8 pieces, and add up these contributions. If we did that, which arrow above would best represent the direction of the net electric field at location A?
#
# ### <center> Important Information
#
# **Objective:** Find the length of the pieces of the rod, the location and charge of the pieces, the electric field due to one of the pieces, and the direction of the net electric field at location A.
#
# **Given Information:**
#
# * Length of the plastic rod.
#
# * The charge of the rod.
#
# * The coordinate system (+x is to the right, +y is up, +z is out of the page)
#
# * Location A
#
# * The rod is broken up into 8 pieces.
#
# * A "point charge" is equal to the center of each of the pieces of the rod.
#
# **Key Equations:**
#
# \begin{equation*}
# \vec{r} = observed - source
# \end{equation*}
#
# \begin{equation*}
# \hat{r} = \frac{\vec{r}}{|\vec{r}|} = \frac{<x,y,z>}{\sqrt{x^{2}+y^{2}+z^{2}}}
# \end{equation*}
#
# \begin{equation*}
# \frac{1}{4\pi\epsilon_{0}} \frac{q}{|\vec{r}|^{2}} \hat{r}
# \end{equation*}
#
# **References:**
#
# Figure 13.16 Direction of Electric field due to a negative source charge (Matter and Interactions, p. 519)
#
# Figure 15.1 Electric field vectors on a positively charged thin rod (Matter and Interactions, p. 588)
#
# 15.1 A Uniformly Charged Thin Rod (Matter and Interactions, p. 588)
#
# **Things to think about:**
#
# * Is the given charge of the rod divided among the segments or does each segment have the same charge as the rod?
#
# * Understand where the coordinate plane is, as given in the problem. Draw it out.
#
# * How would you get the net electric field at A?
#
# * If the rod had a uniform charge that was positive, how would the answers to this problem change?
#
# ___
#
# ## <center> 15.28
#
# ___
#
# ### <center> Skills Involved
#
# Location of the center of an object/segment
#
# * Vector notation
#
# * Finding the origin based on a given location
#
# Charge of a segment
#
# * Uniform charge density
#
# Setting up r-vector and finding the unit vector
#
# Electric field due to a point charge
#
# Net electric field due to multiple sources
#
# Evaluating the accuracy of an approximation
#
# ### <center> Problem
#
# ![](Graphics/P15.28.png "Problem 15.28 - Matter and Interactions")
#
# a) What is the approximate electric field at A due to piece 1?
#
# b) What is the approximate electric field at A due to piece 2?
#
# c) What is the approximate electric field at A due to piece 3?
#
# d) What is the approximate net electric field at A?
#
# e) What could you do to improve the accuracy of your calculation?
#
# ### <center> Important Information
#
# **Objective:** Find the electric field at A due to the three pieces of tape, find the net electric field at A, and understand the effect of accurate approximations.
#
# **Given Information:**
#
# * Length of tape
#
# * Width of tape
#
# * The tape is charged uniformly
#
# * Total net charge
#
# * Location of A
#
# * Tape is divided into three equal sections
#
# **Key Equations**
#
# **References:**
#
# **Things to think about**
#
# ___
#
# ### <center> 15.26
#
# ___
#
# ![](Graphics/P15.26.png "Problem 15.26 - Matter and Interactions")
#
# Calculate the initial acceleration of the speck of coal dust, neglecting gravity. Don't put numbers into your calculation until the very end, but then show the numerical calculation that you carry out on your calculator (Enter the magnitude).
#
# b) If the speck of coal dust were initially nine times as far from the charged wire, how much smaller would be the initial acceleration of the speck?
#
# ### <center> Important Information
#
# **Objective:** Construct an equation to calculate the initial acceleration and then use it to calculate the initial acceleration of the speck of coal dust. Understand how distance changes the initial acceleration.
#
# **Given Information:**
#
# * Straight metal wire length
#
# * Metal wire total charge
#
# * Speck of coal dust (carbon) is near the wire
#
# * Distance from the wire to the speck
#
# * Carbon has 6 protons and 6 neutrons
#
# * Polarizability of a carbon atom
#
# **Key Equations**
#
# **References:**
#
# **Things to think about**
