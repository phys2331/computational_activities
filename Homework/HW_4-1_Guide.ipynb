# %% [markdown]
# # <center> Homework 4-1 Guide
#
# ___
#
# ## <center> 16.33
# ___
#
# ### <center> Skills Involved
#
# Potential
#
# * Defintion
#
# Integration
#
# * Setting up a path integral along a straight line.
#
# Dot Products
#
# Integration
#
# ### <center> Problem
#
# ![](Graphics/P16.33.png "Problem 16.33 - Matter and Interactions")
#
# ### <center> Important Information
#
# **Objective:** Find the magnitude of the electric field in the given region.
#
# **Given Information:**
#
# * Two locations (A and B) are in a uniform electric field.
#
# * Change in potential.
#
# * Distance between A and B.
#
# **Key Equations:**
#
# **References:**
#
# **Things to think about:**
#
# ___
#
# ## <center> 16.35
# ___
#
# ### <center> Skills Involved
#
# Electric Field
#
# * Capacitor
#
# * Infinite plate
#
# Potential
#
# * Definition
#
# Integration
#
# * Setting up a path integral along a straight line.
#
# Dot Products
#
# ### <center> Problem
#
# If the electric field exceeds about $3 \times 10^{6}$ N/C in air, a spark occurs. Approximately, what is the maximum possible potential difference between the plates of a capacitor whose gap is 1 mm, without causing a spark in the air between them?
#
# ### <center> Important Information
#
# **Objective:** Find the maximum potential difference between the plates of a capacitor that won't cause a spark.
#
# **Given Information:**
#
# * Electric field threshold value in which a spark could occur.
#
# * Distance between the plates of the capacitor.
#
# **Key Equations:**
#
# **References:**
#
# **Things to think about:**
#
# ___
#
# ## <center> 16.40
# ___
#
# ### <center> Skills Involved
#
# Potential Difference vs Potential Energy
#
# Potential Energy vs Kinetic Energy
#
# Kenetic Energy vs Velocity
#
# Dot Products
#
# ### <center> Problem
#
# ![](Graphics/P16.40.png "Problem 16.40 - Matter and Interactions")
#
# ### <center> Important Information
#
# **Objective:** Find the velocity of electrons as they travel from the negative plate through the positive plate of a TV.
#
# **Given Information:**
#
# * Electrons are accelerating from the negative plate to the positive plate.
#
# * Potential difference between the two plates.
#
# **Key Equations:**
#
# **References:**
#
# **Things to think about:**
#
# ___
#
# ## <center> 16.66
# ___
#
# ### <center> Skills Involved
#
# Electric Field
#
# * Capacitor
#
# * Infinite disk
#
# Vectors
#
# * Formatting
#
# Potential Difference
#
# Integration
#
# * Setting up a path along a straight line
#
# Dot Products
#
# ### <center> Problem
#
# ![](Graphics/P16.66.png "Problem 16.66 - Matter and Interactions")
#
# Part 1:
#
# What is the electric field inside the capacitor?
#
# Part 2:
#
# Calculate the potential difference $V_{B}-V_{A}$.
#
# What is the $\Delta \vec{l}$ along this path?
#
# What is $V_{B} - V_{A}$?
#
# Part 3:
#
# Calculate the potential difference $V_{C}-V_{B}$.
#
# What is the $\Delta \vec{l}$ along this path?
#
# What is $V_{C} - V_{B}$?
#
# Part 4:
#
# Calculate the potential difference $V_{A}-V_{C}$.
#
# What is the $\Delta \vec{l}$ along this path?
#
# What is $V_{A} - V_{C}$?
#
# ### <center> Important Information
#
# **Objective:** Find the electric field and potential differences between various points within a capacitor.
#
# **Given Information:**
#
# * Radius of the two disks.
#
# * Distance between the two disks.
#
# * Magnitude of the charge on each disk.
#
# * Distances between the points ($s_{1}$ and $s_{2}$).
#
# **Key Equations:**
#
# **References:**
#
# **Things to think about:**
#
# ___
#
# ## <center> 16.66 Alternate 01
# ___
#
# ### <center> Skills Involved
#
# Electric Field
#
# * Capacitor
#
# * Infinite disk
#
# Vectors
#
# * Formatting
#
# Potential Difference
#
# Integration
#
# * Setting up a path along a straight line
#
# Dot Products
#
# ### <center> Problem
#
# ![](Graphics/P16.66alt1.png "Problem 16.66alt01 - Matter and Interactions")
#
# Part 1:
#
# What is the magnitude of the electric field inside the capacitor?
#
# Part 2:
#
# Calculate the following potential differences:
#
# $V_{B}-V_{A}$
#
# $V_{C}-V_{B}$
#
# $V_{C}-V_{A}$
#
# Part 3:
#
# Consider diagonal path A-C.
#
# Along this path, $\Delta V = E\Delta L cos(\theta)$.
#
# If $\theta$ is the angle between $\vec{E}$ and the displacement $\Delta \vec{L}$, then what is $\Delta L cos(\theta)$?
#
# What is $\Delta V$ along the diagonal path from A to C?
#
# ### <center> Important Information
#
# **Objective:** Find the electric field and potential differences between various points within a capacitor.
#
# **Given Information:**
#
# * Radius of the two disks.
#
# * Distance between the two disks.
#
# * Magnitude of the charge on each disk.
#
# * Distances between the points ($s_{1}$ and $s_{2}$).
#
# **Key Equations:**
#
# **References:**
#
# **Things to think about:**
